# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

def tokenize_text(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as file:
        text = file.read()

    sentences = text.split("\n")
    tokens = []

    for sentence in sentences:
        if sentence.strip():
            tokens.append("<s>")
            sentence_tokens = word_tokenize(sentence)
            tokens.extend(sentence_tokens)
            tokens.append("</s>")
            tokens.append("\n")

    with open(output_file, 'w', encoding='utf-8') as out_file:
        out_file.write(" ".join(tokens))

if __name__ == "__main__":
    input_file = "/content/chats listos.txt"
    output_file = "chats.txt"
    tokenize_text(input_file, output_file)
    print("Tokens guardados en", output_file)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Tokens guardados en chatsTokenizados.txt
